# %%
import pandas as pd
import time
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
file_path = r"m.xlsx"
data1 = pd.read_excel(file_path)
a = data1.tail(500)
a.head(5)
a.tail(5)
# Out:
#            date  1. open  2. high   3. low  4. close  5. volume
# 5254 2020-09-18   202.80   203.65  196.250    200.39   55225326
# 5255 2020-09-21   197.19   202.71  196.380    202.54   39839657
# 5256 2020-09-22   205.06   208.10  202.075    207.42   33517065
# 5257 2020-09-23   207.90   208.10  200.030    200.59   30803780
# 5258 2020-09-24   199.85   205.57  199.200    203.19   31202493

# %%
file_path = r"stesla.xlsx"
data2 = pd.read_excel(file_path)
b = data2.head(30)
b.head(5)
# Out:
#         date  1. open  2. high  3. low  4. close  5. volume
# 0 2020-05-05   789.79   798.92  762.18    768.21   16991700
# 1 2020-05-06   776.50   789.80  761.11    782.58   11123200
# 2 2020-05-07   777.21   796.40  772.35    780.04   11527700
# 3 2020-05-08   793.77   824.00  787.01    819.42   16130100
# 4 2020-05-11   790.51   824.00  785.00    811.29   16519600

# %%
file_path = r"ibm.xlsx"
data3 = pd.read_excel(file_path)
c = data3.head(30)
c.head(5)
# Out:
#         date  1. open  2. high  3. low  4. close  5. volume
# 0 2020-05-05   123.39   124.32  122.47    122.58    3899400
# 1 2020-05-06   123.24   124.05  122.41    123.17    3864600
# 2 2020-05-07   122.98   123.26  120.85    121.23    4412600
# 3 2020-05-08   122.67   123.23  121.06    122.99    5003900
# 4 2020-05-11   121.81   123.45  120.67    122.59    3535300

# %%
file_path = r"google.xlsx"
data4 = pd.read_excel(file_path)
d = data4.head(30)
d.head(5)
# Out:
#         date  1. open  2. high   3. low  4. close  5. volume
# 0 2020-05-05  1337.92  1373.94  1337.46   1351.11    1651533
# 1 2020-05-06  1361.69  1371.12  1347.29   1347.30    1215423
# 2 2020-05-07  1365.94  1377.60  1355.27   1372.56    1399759
# 3 2020-05-08  1383.13  1398.76  1375.48   1388.37    1388068
# 4 2020-05-11  1378.28  1416.53  1377.15   1403.26    1412116

# %%
file_path = r"facebook.xlsx"
data5 = pd.read_excel(file_path)
e = data5.head(30)
e.head(5)
# Out:
#         date   1. open  2. high  3. low  4. close  5. volume
# 0 2020-05-05  207.0200   210.38  206.50    207.07   21071223
# 1 2020-05-06  208.1200   211.60  206.66    208.47   21856963
# 2 2020-05-07  211.1600   211.60  209.04    211.26   15151976
# 3 2020-05-08  212.2400   213.21  210.85    212.35   12524048
# 4 2020-05-11  210.8865   215.00  210.37    213.18   12911948

# %%
file_path = r"amazon.xlsx"
data6 = pd.read_excel(file_path)
f = data6.head(30)
f.head(5)
# Out:
#         date  1. open  2. high   3. low  4. close  5. volume
# 0 2020-05-05  2340.00  2351.00  2307.13   2317.80    3242496
# 1 2020-05-06  2329.44  2357.45  2320.00   2351.26    3117814
# 2 2020-05-07  2374.78  2376.00  2343.11   2367.61    3396411
# 3 2020-05-08  2372.14  2387.24  2357.00   2379.61    3211228
# 4 2020-05-11  2374.70  2419.66  2372.11   2409.00    3259231

# %%
print("MICROSOFT\n",data1.isna().any())
print("TESLA\n",data2.isna().any())
print("IBM\n",data3.isna().any())
print("ALPHABET\n",data4.isna().any())
print("FACEBOOK\n",data5.isna().any())
print("AMAZON\n",data6.isna().any())
# Out:
# MICROSOFT
#  date         False
# 1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# TESLA
#  date         False
# 1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# IBM
#  date         False
# 1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# ALPHABET
#  date         False
# 1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# FACEBOOK
#  date         False
# 1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# AMAZON
#  date         False
# 1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool

# %% [markdown]
# <h2>VISUALIZING THE PREVIOUS DATASETS</h2>

# %%
plt.figure(figsize = (40,15))
plt.subplot(2,3,1)
sns.heatmap(data1.corr(),annot = True, cmap = "gnuplot2_r")
plt.subplot(2,3,2)
sns.heatmap(data2.corr(),annot = True, cmap = "nipy_spectral")
plt.subplot(2,3,3)
sns.heatmap(data3.corr(),annot = True, cmap = "inferno")
plt.subplot(2,3,4)
sns.heatmap(data4.corr(),annot = True, cmap = "copper")
plt.subplot(2,3,5)
sns.heatmap(data5.corr(),annot = True, cmap = "magma_r")
plt.subplot(2,3,6)
sns.heatmap(data6.corr(),annot = True, cmap = "mako")

# %% [markdown]
# <h3>MICROSOFT</h3>

# %%
val1 = data1.groupby(['date'])["1. open"].sum()
val2 = data1.groupby(['date'])["2. high"].sum()
val3 = data1.groupby(['date'])["3. low"].sum()
val4 = data1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (20,10))
plt.plot(val1, color = "b", ls = "-", label = "OPEN",markeredgecolor = "k", lw = 0.7)
plt.plot(val2, color = "r", ls = "-",label = "HIGH",markeredgecolor = "k",lw = 0.7)
plt.plot(val3, color = "k", ls = "-", label = "LOW",markeredgecolor = "k",lw = 0.7)
plt.plot(val4, color = "g", ls = "-", label = "CLOSE",markeredgecolor = "k",lw= 0.7)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "k", ls = "-",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)

# %% [markdown]
# <h3>TESLA</h3>

# %%
val1 = b.groupby(['date'])["1. open"].sum()
val2 = b.groupby(['date'])["2. high"].sum()
val3 = b.groupby(['date'])["3. low"].sum()
val4 = b.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.7)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.7)
plt.plot(val3, color = "k", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.7)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.7)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,12))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "k", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737553., 737560., 737567., 737577., 737584., 737591.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h3>IBM</h3>

# %%
val1 = c.groupby(['date'])["1. open"].sum()
val2 = c.groupby(['date'])["2. high"].sum()
val3 = c.groupby(['date'])["3. low"].sum()
val4 = c.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "--", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "k", ls = "--", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "--", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "k", ls = "--", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737553., 737560., 737567., 737577., 737584., 737591.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h3>ALPHABET</h3>

# %%
val1 = d.groupby(['date'])["1. open"].sum()
val2 = d.groupby(['date'])["2. high"].sum()
val3 = d.groupby(['date'])["3. low"].sum()
val4 = d.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "purple", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "violet", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737553., 737560., 737567., 737577., 737584., 737591.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h3>FACEBOOK</h3>

# %%
val1 = e.groupby(['date'])["1. open"].sum()
val2 = e.groupby(['date'])["2. high"].sum()
val3 = e.groupby(['date'])["3. low"].sum()
val4 = e.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 1.2)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 1.2)
plt.plot(val3, color = "purple", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 1.2)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 1.2)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "violet", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737553., 737560., 737567., 737577., 737584., 737591.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h3>AMAZON</h3>

# %%
val1 = f.groupby(['date'])["1. open"].sum()
val2 = f.groupby(['date'])["2. high"].sum()
val3 = f.groupby(['date'])["3. low"].sum()
val4 = f.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "purple", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "violet", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737553., 737560., 737567., 737577., 737584., 737591.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h2>MACHINE LEARNING</h2>

# %% [markdown]
# <h3>Linear Regression</h3>

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
X = a[['2. high','3. low','1. open','5. volume']].values
Y = a[['4. close']].values

# %%
# X_train,X_test,y_train,y_test= train_test_split(X,Y,test_size=0.15,random_state=0)
# LR1= LinearRegression()
# LR1.fit(X_train,y_train)
# LR1.score(X_test,y_test)
# print(LR1.coef_)
# print(LR1.intercept_)

# %%
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error
pred_lin= LR1.predict(X_test)
# R2 score evaluation on linear reg 
r2_lin = r2_score(y_test , pred_lin)
print("R2 score for LR: ", r2_lin)

#  Mean absoulte error on linear regression 
mae_lin = mean_absolute_error(y_test ,pred_lin)
print("Mean Absolute Error on LR: ",mae_lin)

# Mean Squared error on linear 
mse_lin = mean_squared_error(y_test , pred_lin)
print("Mean Squared Error on LR: ", mse_lin)
# Out:
# R2 score for LR:  0.9978833142962984
# Mean Absolute Error on LR:  0.8902923042102333
# Mean Squared Error on LR:  2.2988600855751713

# %%
df = {'Actual values':y_test ,'Predicted values':pred_lin}
df['Differences'] = df['Predicted values'] - df['Actual values']
df['Profit/Lost %'] = (df['Differences']*100)/ df['Actual values']
pd.DataFrame([df])
df
# Out:
# {'Actual values': array([[105.25],
#         [138.12],
#         [148.06],
#         [214.32],
#         [205.01],
#         [109.63],
#         [158.62],
#         [205.37],
#         [126.9 ],
#         [123.35],
#         [137.39],
#         [139.03],
#         [167.82],
#         [149.59],
#         [131.4 ],
#         [166.72],
#         [203.38],
#         [172.79],
#         [124.73],
#         [103.11],
#         [141.34],
#         [146.57],
#         [136.33],
#         [110.51],
#         [108.52],
#         [198.44],
#         [103.73],
#         [140.4 ],
#         [107.15],
#         [140.05],
#         [188.94],
#         [117.05],
#         [119.02],
#         [136.96],
#         [149.7 ],
#         [208.78],
#         [158.67],
#         [202.88],
#         [158.18],
#         [137.52],
#         [163.28],
#         [109.19],
#         [184.68],
#         [138.41],
#         [105.68],
#         [115.15],
#         [135.28],
#         [166.17],
#         [182.83],
#         [112.03],
#         [139.06],
#         [127.82],
#         [184.71],
#         [130.6 ],
#         [120.33],
#         [110.71],
#         [166.5 ],
#         [132.1 ],
#         [137.78],
#         [184.44],
#         [106.2 ],
#         [144.46],
#         [177.04],
#         [196.84],
#         [151.7 ],
#         [138.9 ],
#         [107.6 ],
#         [209.19],
#         [142.83],
#         [107.71],
#         [129.89],
#         [101.93],
#         [183.89],
#         [231.65],
#         [132.32]]),
#  'Predicted values': array([[105.74706192],
#         [137.85888785],
#         [148.31431747],
#         [212.6665647 ],
#         [200.68360487],
#         [109.60130649],
#         [159.61621209],
#         [207.43397511],
#         [127.06542178],
#         [124.49901858],
#         [137.19264275],
#         [138.98657065],
#         [167.77413151],
#         [149.50014029],
#         [131.04433484],
#         [166.14366543],
#         [204.47146673],
#         [168.9969367 ],
#         [125.51541724],
#         [103.32546174],
#         [141.56858929],
#         [141.97300381],
#         [136.609792  ],
#         [110.30535382],
#         [109.56943356],
#         [196.45242957],
#         [101.22320763],
#         [141.91938758],
#         [106.8674477 ],
#         [139.98513158],
#         [189.37633273],
#         [117.7062378 ],
#         [118.55530556],
#         [-3.13638274],
#         [ 0.20523142],
#         [-0.18518341],
#         [ 0.96704161],
#         [-1.00159768],
#         [-2.41665128],
#         [ 1.08218489],
#         [-0.2636979 ],
#         [-0.04631804],
#         [ 0.23093719],
#         [ 0.56064742],
#         [-0.39043391],
#         [-0.42045092],
#         [ 1.65893179],
#         [-0.11592715],
#         [-0.03239092],
#         [-0.1320812 ],
#         [ 2.23554165],
#         [ 0.09474559],
#         [-0.2736132 ],
#         [-1.18341031],
#         [-0.48728817],
#         [-0.43815009],
#         [-0.05360694],
#         [ 0.07765732],
#         [-1.04957091],
#         [-0.23021497],
#         [-0.33910341],
#         [ 0.47127047],
#         [ 5.27533862],
#         [-0.47282645],
#         [-1.02759386],
#         [-0.20167806],
#         [ 0.17413529],
#         [-0.41590849],
#         [ 0.77613912],
#         [ 0.15908506],
#         [-0.22370222],
#         [ 0.32267247],
#         [-0.24590937],
#         [-0.0637859 ],
#         [-0.8480792 ],
#         [ 0.1368756 ],
#         [-0.42786251],
#         [ 0.04266966],
#         [ 0.29530165],
#         [-0.03947341],
#         [ 0.45664997],
#         [-1.02025659],
#         [ 0.06643516],
#         [-0.57036419],
#         [ 0.5417743 ],
#         [-0.03387904],
#         [ 0.28094115]])}

# %%
plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(data1['4. close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation = 60)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.]),
#  <a list of 8 Text xticklabel objects>)

# %%
df = a[['4. close']]
df.head(5)
# Out:
#       4. close
# 4759    115.61
# 4760    115.15
# 4761    115.17
# 4762    112.79
# 4763    112.13

# %%
future_days = 10
df['Predictions'] = df[['4. close']].shift(-future_days)
df.tail(5)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       4. close  Predictions
# 5254    200.39          NaN
# 5255    202.54          NaN
# 5256    207.42          NaN
# 5257    200.59          NaN
# 5258    203.19          NaN

# %%
X = np.array(df.drop(['Predictions'],1))[:-future_days]
print(X)
# Out:
# [[115.61]
#  [115.15]
#  [115.17]
#  [112.79]
#  [112.13]
#  [110.85]
#  [112.26]
#  [106.16]
#  [105.91]
#  [109.57]
#  [107.6 ]
#  [111.  ]
#  [110.71]
#  [108.5 ]
#  [108.66]
#  [109.63]
#  [108.1 ]
#  [102.32]
#  [108.3 ]
#  [106.96]
#  [103.85]
#  [103.73]
#  [106.81]
#  [105.92]
#  [106.16]
#  [107.51]
#  [107.72]
#  [111.96]
#  [111.75]
#  [109.57]
#  [106.87]
#  [106.94]
#  [104.97]
#  [107.28]
#  [108.29]
#  [104.62]
#  [101.71]
#  [103.11]
#  [103.07]
#  [106.47]
#  [107.14]
#  [111.12]
#  [110.19]
#  [110.89]
#  [112.09]
#  [108.52]
#  [109.19]
#  [104.82]
#  [107.59]
#  [108.59]
#  [109.08]
#  [109.45]
#  [106.03]
#  [102.89]
#  [103.97]
#  [103.69]
#  [101.51]
#  [ 98.23]
#  [ 94.13]
#  [100.56]
#  [101.18]
#  [100.39]
#  [101.57]
#  [101.12]
#  [ 97.4 ]
#  [101.93]
#  [102.06]
#  [102.8 ]
#  [104.27]
#  151.13 151.7  153.24 154.53 155.53 154.69 154.37 155.71 157.41 157.41
#  157.38 158.67 158.96 157.59 157.7  160.62 158.62 159.03 157.58 160.09
#  162.09 161.34 163.28 162.13 163.18 166.17 167.1  166.5  165.7  166.72
#  165.04 162.28 165.46 168.04 172.78 170.23 174.38 180.12 179.9  183.63
#  183.89 188.7  184.44 184.71 183.71 185.35 187.23 187.28 184.42 178.59
#  170.89 168.07 170.17 158.18 162.01 172.79 164.51 170.55 166.27 161.57
#  150.62 160.92 153.63 139.06 158.83 135.42 146.57 140.4  142.71 137.35
#  135.98 148.34 146.92 156.11 149.7  160.23 157.71 152.11 155.26 153.83
#  165.27 163.49 165.13 165.14 165.51 173.7  171.88 177.04 178.6  175.06
#  167.82 173.52 171.42 174.55 174.05 169.81 177.43 179.21 174.57 178.84
#  180.76 182.54 183.6  184.68 186.74 182.51 179.75 180.53 183.16 184.91
#  183.63 185.66 183.43 183.51 181.57 181.81 181.4  183.25 182.83 184.91
#  185.36 182.92 187.2  188.36 189.8  196.84 186.27 187.74 188.94 193.57
#  194.24 196.32 195.15 200.57 201.91 197.84 200.34 196.33 198.44 203.51
#  204.7  206.26 210.7  208.25 212.83 214.32 213.67 207.07 208.35 208.04
#  203.92 202.88 211.6  208.75 211.75 202.54 201.3  203.85 202.02 204.06
#  203.9  205.01 216.54 213.29 212.94 216.35 212.48 208.25 203.38 209.19
#  208.7  208.9  210.28 211.49 209.7  214.58 213.02 213.69 216.47 221.15
#  226.58 228.91 225.53 227.27 231.65 217.3  214.25 202.66 211.29 205.37
#  204.03 205.41 208.78 205.05 202.91 200.39 202.54 207.42 200.59 203.19]

# %%
# Split
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = 0.15)

# %%
# models
# decision tree reg model
tree = DecisionTreeRegressor().fit(x_train,y_train)
# linear model
lr = LinearRegression().fit(x_train, y_train)

# %%
x_future = df.drop(['Predictions'],1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# array([[226.58],
#        [228.91],
#        [225.53],
#        [227.27],
#        [231.65],
#        [217.3 ],
#        [214.25],
#        [202.66],
#        [211.29],
#        [205.37]])

# %%
# model tree pred
tree_prediction = tree.predict(x_future)
print(tree_prediction)
print()
# linear
lr_pred = lr.predict(x_future)
print(lr_pred)
# Out:
# [205.05 205.41 208.78 205.05 205.41 200.39 202.54 207.42 200.59 203.19]
#
# [228.7013552  231.03033881 227.65181323 229.39105421 233.76914358
#  219.42540329 216.37673375 204.7917895  213.41802495 207.50060735]

# %%
# visualize
predictions = tree_prediction
valid = df[X.shape[0]:]
valid['Predictions'] = predictions
plt.figure(figsize = (18,8))
plt.xlabel('Days')
plt.ylabel('Closing price')
plt.plot(df['4. close'])
plt.plot(valid[['4. close', 'Predictions']])
plt.legend(['Orig','Valid','Pred'])
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
predictions = lr_pred
valid = df[X.shape[0]:]
valid['Predictions'] = predictions
plt.figure(figsize = (18,8))
plt.xlabel('Days')
plt.ylabel('Closing price')
plt.plot(df['4. close'])
plt.plot(valid[['4. close', 'Predictions']])
plt.legend(['Orig','Valid','Pred'])
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
