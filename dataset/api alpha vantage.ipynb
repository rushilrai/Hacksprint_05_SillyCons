# %%
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
import time
import requests
import seaborn as sns
import matplotlib.pyplot as plt

# %%
key_for_api = 'YQE391GAVYXAMF5H'

# %%
time_duration = TimeSeries(key = key_for_api, output_format = 'pandas')

# %% [markdown]
# <h1>Given datasets are in USD</h1>

# %%
# 1. MICROSOFT
# data2 is a metadata which is used for finding data and instances easily
data1, data2 = time_duration.get_daily(symbol = 'MSFT', outputsize = 'full')
data1
# Out:
#             1. open  2. high   3. low  4. close   5. volume
# date
# 2020-09-23   207.90   208.10  200.030    200.59  30803780.0
# 2020-09-22   205.06   208.10  202.075    207.42  33517065.0
# 2020-09-21   197.19   202.71  196.380    202.54  39839657.0
# 2020-09-18   202.80   203.65  196.250    200.39  55225326.0
# 2020-09-17   200.05   204.33  199.960    202.91  34011257.0
# ...             ...      ...      ...       ...         ...
# 1999-11-05    91.81    92.87   90.500     91.56  35083700.0
# 1999-11-04    92.31    92.75   90.310     91.75  27119700.0
# 1999-11-03    92.94    93.50   91.500     92.00  22258500.0
# 1999-11-02    92.75    94.50   91.940     92.56  23174500.0
# 1999-11-01    93.25    94.19   92.120     92.37  26630600.0
#
# [5258 rows x 5 columns]

# %%
data1.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. volume'], dtype='object')

# %%
c = data1.head(100)
c
# Out:
#             1. open  2. high   3. low  4. close   5. volume
# date
# 2020-09-23   207.90   208.10  200.030    200.59  30803780.0
# 2020-09-22   205.06   208.10  202.075    207.42  33517065.0
# 2020-09-21   197.19   202.71  196.380    202.54  39839657.0
# 2020-09-18   202.80   203.65  196.250    200.39  55225326.0
# 2020-09-17   200.05   204.33  199.960    202.91  34011257.0
# ...             ...      ...      ...       ...         ...
# 2020-05-08   184.98   185.00  183.360    184.68  30912638.0
# 2020-05-07   184.17   184.55  182.580    183.60  28315992.0
# 2020-05-06   182.08   184.20  181.630    182.54  32139299.0
# 2020-05-05   180.62   183.65  179.900    180.76  36839168.0
# 2020-05-04   174.49   179.00  173.800    178.84  30372862.0
#
# [100 rows x 5 columns]

# %%
dataset = pd.ExcelWriter("microsoft.xlsx", engine = 'xlsxwriter')
c.to_excel(dataset, sheet_name='Sheet1')
dataset.save()

# %%
#2. TESLA
data, metadata = time_duration.get_daily(symbol = 'TSLA', outputsize = 'full')
d = data.head(100)
d
# Out:
#             1. open  2. high    3. low  4. close    5. volume
# date
# 2020-09-23   405.16   412.15  375.8801    380.36   95074176.0
# 2020-09-22   429.60   437.76  417.6001    424.23   79580795.0
# 2020-09-21   453.13   455.68  407.0700    449.39  109476800.0
# 2020-09-18   447.94   451.00  428.8000    442.15   86406819.0
# 2020-09-17   415.60   437.79  408.0001    423.43   76779163.0
# ...             ...      ...       ...       ...          ...
# 2020-05-08   793.77   824.00  787.0100    819.42   16130100.0
# 2020-05-07   777.21   796.40  772.3500    780.04   11527700.0
# 2020-05-06   776.50   789.80  761.1100    782.58   11123200.0
# 2020-05-05   789.79   798.92  762.1800    768.21   16991700.0
# 2020-05-04   701.00   762.00  698.0000    761.19   19237100.0
#
# [100 rows x 5 columns]

# %%
dataset = pd.ExcelWriter("stesla.xlsx", engine = 'xlsxwriter')
d.to_excel(dataset, sheet_name='Sheet1')
dataset.save()

# %%
# 3. IBM
data, metadata = time_duration.get_daily(symbol = 'IBM', outputsize = 'full')
e = data.head(100)
e
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2020-09-23   120.80   121.59  118.43    118.83  3939398.0
# 2020-09-22   120.33   121.45  119.53    120.51  2957809.0
# 2020-09-21   120.48   120.70  118.58    120.25  5311441.0
# 2020-09-18   124.26   124.92  122.65    122.76  5391570.0
# 2020-09-17   122.62   125.55  121.97    124.92  3171262.0
# ...             ...      ...     ...       ...        ...
# 2020-05-08   122.67   123.23  121.06    122.99  5003900.0
# 2020-05-07   122.98   123.26  120.85    121.23  4412600.0
# 2020-05-06   123.24   124.05  122.41    123.17  3864600.0
# 2020-05-05   123.39   124.32  122.47    122.58  3899400.0
# 2020-05-04   120.82   121.97  119.39    121.68  4017900.0
#
# [100 rows x 5 columns]

# %%
dataset = pd.ExcelWriter("ibm.xlsx", engine = 'xlsxwriter')
e.to_excel(dataset, sheet_name='Sheet1')
dataset.save()

# %%
# 4. ALPHABET class c
data, metadata = time_duration.get_daily(symbol = 'GOOG', outputsize = 'full')
f = data.head(100)
f
# Out:
#             1. open    2. high     3. low  4. close  5. volume
# date
# 2020-09-23  1458.78  1460.9600  1407.7000   1415.21  1657350.0
# 2020-09-22  1450.09  1469.5200  1434.5300   1465.46  1583201.0
# 2020-09-21  1440.06  1448.3600  1406.5500   1431.16  2888827.0
# 2020-09-18  1498.01  1503.0032  1437.1300   1459.99  3103882.0
# 2020-09-17  1496.00  1508.2984  1470.0001   1495.53  1879751.0
# ...             ...        ...        ...       ...        ...
# 2020-05-08  1383.13  1398.7600  1375.4800   1388.37  1388068.0
# 2020-05-07  1365.94  1377.6000  1355.2700   1372.56  1399759.0
# 2020-05-06  1361.69  1371.1200  1347.2900   1347.30  1215423.0
# 2020-05-05  1337.92  1373.9400  1337.4600   1351.11  1651533.0
# 2020-05-04  1308.23  1327.6600  1299.0000   1326.80  1504017.0
#
# [100 rows x 5 columns]

# %%
dataset = pd.ExcelWriter("google.xlsx", engine = 'xlsxwriter')
f.to_excel(dataset, sheet_name='Sheet1')
dataset.save()

# %%
# 5. FACEBOOK
data1, data2 = time_duration.get_daily(symbol = 'FB', outputsize = 'full')
g = data1.head(100)
g
# Out:
#             1. open   2. high    3. low  4. close   5. volume
# date
# 2020-09-23  255.260  257.9921  248.1500    249.02  19641266.0
# 2020-09-22  253.310  255.3200  248.2200    254.75  30293103.0
# 2020-09-21  247.540  249.9500  244.1300    248.15  24709378.0
# 2020-09-18  258.405  259.2000  250.0500    252.53  28130767.0
# 2020-09-17  258.280  261.5000  250.1900    254.82  31281441.0
# ...             ...       ...       ...       ...         ...
# 2020-05-08  212.240  213.2100  210.8500    212.35  12524048.0
# 2020-05-07  211.160  211.6000  209.0400    211.26  15151976.0
# 2020-05-06  208.120  211.6000  206.6600    208.47  21856963.0
# 2020-05-05  207.020  210.3800  206.5000    207.07  21071223.0
# 2020-05-04  200.200  205.9100  198.7562    205.26  19250673.0
#
# [100 rows x 5 columns]

# %%
dataset = pd.ExcelWriter("facebook.xlsx", engine = 'xlsxwriter')
g.to_excel(dataset, sheet_name='Sheet1')
dataset.save()

# %%
# 6. AMAZON
data1, data2 = time_duration.get_daily(symbol = 'AMZN', outputsize = 'full')
h = data1.head(100)
h
# Out:
#              1. open   2. high     3. low  4. close  5. volume
# date
# 2020-09-23  3120.430  3126.999  2992.3759   2999.86  5652665.0
# 2020-09-22  3033.835  3133.990  3000.2000   3128.99  6948816.0
# 2020-09-21  2906.500  2962.000  2871.0000   2960.47  6117925.0
# 2020-09-18  3031.740  3037.800  2905.5400   2954.91  8892580.0
# 2020-09-17  3009.250  3029.432  2972.5500   3008.73  6449050.0
# ...              ...       ...        ...       ...        ...
# 2020-05-08  2372.140  2387.240  2357.0000   2379.61  3211228.0
# 2020-05-07  2374.780  2376.000  2343.1100   2367.61  3396411.0
# 2020-05-06  2329.440  2357.450  2320.0000   2351.26  3117814.0
# 2020-05-05  2340.000  2351.000  2307.1300   2317.80  3242496.0
# 2020-05-04  2256.380  2326.980  2256.3800   2315.99  4865926.0
#
# [100 rows x 5 columns]

# %%
dataset = pd.ExcelWriter("amazon.xlsx", engine = 'xlsxwriter')
h.to_excel(dataset, sheet_name='Sheet1')
dataset.save()

# %%
print("MICROSOFT\n",c.isna().any())
print("TESLA\n",d.isna().any())
print("IBM\n",e.isna().any())
print("ALPHABET\n",f.isna().any())
print("FACEBOOK\n",g.isna().any())
print("AMAZON\n",h.isna().any())
# Out:
# MICROSOFT
#  1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# TESLA
#  1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# IBM
#  1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# ALPHABET
#  1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# FACEBOOK
#  1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool
# AMAZON
#  1. open      False
# 2. high      False
# 3. low       False
# 4. close     False
# 5. volume    False
# dtype: bool

# %% [markdown]
# <h4>VISUALIZING THE DATA</h4>

# %%
plt.figure(figsize = (40,15))
plt.subplot(2,3,1)
sns.heatmap(c.corr(),annot = True, cmap = "gnuplot2_r")
plt.subplot(2,3,2)
sns.heatmap(d.corr(),annot = True, cmap = "nipy_spectral")
plt.subplot(2,3,3)
sns.heatmap(e.corr(),annot = True, cmap = "inferno")
plt.subplot(2,3,4)
sns.heatmap(f.corr(),annot = True, cmap = "copper")
plt.subplot(2,3,5)
sns.heatmap(g.corr(),annot = True, cmap = "magma_r")
plt.subplot(2,3,6)
sns.heatmap(h.corr(),annot = True, cmap = "mako")

# %% [markdown]
# <h2>MICROSOFT</H2>

# %%
c1 = c.head(30)
c1
# Out:
#             1. open   2. high    3. low  4. close   5. volume
# date
# 2020-09-23   207.90  208.1000  200.0300    200.59  30803780.0
# 2020-09-22   205.06  208.1000  202.0750    207.42  33517065.0
# 2020-09-21   197.19  202.7100  196.3800    202.54  39839657.0
# 2020-09-18   202.80  203.6500  196.2500    200.39  55225326.0
# 2020-09-17   200.05  204.3300  199.9600    202.91  34011257.0
# 2020-09-16   210.62  210.6500  204.6400    205.05  26372464.0
# 2020-09-15   208.42  209.7800  206.9300    208.78  21823942.0
# 2020-09-14   204.24  209.2000  204.0300    205.41  30375768.0
# 2020-09-11   207.20  208.6300  201.2400    204.03  33620073.0
# 2020-09-10   213.40  214.7400  204.1100    205.37  35461514.0
# 2020-09-09   207.60  214.8399  206.7000    211.29  45678986.0
# 2020-09-08   206.50  210.0300  202.2000    202.66  52924330.0
# 2020-09-04   215.10  218.3599  205.1900    214.25  59664072.0
# 2020-09-03   229.27  229.3100  214.9602    217.30  58400288.0
# ...

# %%
val1 = c1.groupby(['date'])["1. open"].sum()
val2 = c1.groupby(['date'])["2. high"].sum()
val3 = c1.groupby(['date'])["3. low"].sum()
val4 = c1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (20,10))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k")
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k")
plt.plot(val3, color = "k", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k")
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k")
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "k", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)

# %% [markdown]
# <h2>TESLA</h2>

# %%
d1 = d.head(30)
d1
# Out:
#              1. open  2. high     3. low  4. close    5. volume
# date
# 2020-09-23   405.160   412.15   375.8801    380.36   95074176.0
# 2020-09-22   429.600   437.76   417.6001    424.23   79580795.0
# 2020-09-21   453.130   455.68   407.0700    449.39  109476800.0
# 2020-09-18   447.940   451.00   428.8000    442.15   86406819.0
# 2020-09-17   415.600   437.79   408.0001    423.43   76779163.0
# 2020-09-16   439.870   457.79   435.3100    441.76   72546760.0
# 2020-09-15   436.560   461.94   430.7000    449.76   97298228.0
# 2020-09-14   380.950   420.00   373.3000    419.62   83020608.0
# 2020-09-11   381.940   382.50   360.5000    372.72   60717459.0
# 2020-09-10   386.210   398.99   360.5600    371.34   84930608.0
# 2020-09-09   356.600   369.00   341.5100    366.28   79465769.0
# 2020-09-08   356.000   368.74   329.8800    330.21  115465691.0
# 2020-09-04   402.810   428.00   372.0201    418.32  110321885.0
# 2020-09-03   407.230   431.80   402.0000    407.00   87596086.0
# ...

# %%
val1 = d1.groupby(['date'])["1. open"].sum()
val2 = d1.groupby(['date'])["2. high"].sum()
val3 = d1.groupby(['date'])["3. low"].sum()
val4 = d1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.7)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.7)
plt.plot(val3, color = "k", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.7)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.7)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,12))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "k", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "^",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737652., 737659., 737669., 737676., 737683., 737690.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h2>IBM<h2>

# %%
e1 = e.head(30)
e1
# Out:
#             1. open   2. high    3. low  4. close  5. volume
# date
# 2020-09-23   120.80  121.5900  118.4300    118.83  3939398.0
# 2020-09-22   120.33  121.4500  119.5300    120.51  2957809.0
# 2020-09-21   120.48  120.7000  118.5800    120.25  5311441.0
# 2020-09-18   124.26  124.9200  122.6500    122.76  5391570.0
# 2020-09-17   122.62  125.5500  121.9700    124.92  3171262.0
# 2020-09-16   122.71  125.8200  122.7100    124.22  3789458.0
# 2020-09-15   122.82  123.4000  122.2400    122.44  2915221.0
# 2020-09-14   122.36  123.3800  121.7600    122.09  3641887.0
# 2020-09-11   121.39  122.7000  120.7300    121.46  3548091.0
# 2020-09-10   122.53  123.5764  120.2400    120.56  3978805.0
# 2020-09-09   122.13  123.7000  121.2900    122.26  3770678.0
# 2020-09-08   122.16  122.8700  120.7100    121.21  5210292.0
# 2020-09-04   124.35  125.3500  121.2400    122.30  6018238.0
# 2020-09-03   128.19  129.9500  123.6500    124.45  5716750.0
# ...

# %%
val1 = e1.groupby(['date'])["1. open"].sum()
val2 = e1.groupby(['date'])["2. high"].sum()
val3 = e1.groupby(['date'])["3. low"].sum()
val4 = e1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "--", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "k", ls = "--", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "--", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "k", ls = "--", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737652., 737659., 737669., 737676., 737683., 737690.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h2>ALPHABET</h2>

# %%
f1 = f.head(30)
f1
# Out:
#               1. open    2. high     3. low  4. close  5. volume
# date
# 2020-09-23  1458.7800  1460.9600  1407.7000   1415.21  1657350.0
# 2020-09-22  1450.0900  1469.5200  1434.5300   1465.46  1583201.0
# 2020-09-21  1440.0600  1448.3600  1406.5500   1431.16  2888827.0
# 2020-09-18  1498.0100  1503.0032  1437.1300   1459.99  3103882.0
# 2020-09-17  1496.0000  1508.2984  1470.0001   1495.53  1879751.0
# 2020-09-16  1555.5400  1562.0000  1519.8200   1520.90  1312299.0
# 2020-09-15  1536.0000  1559.5700  1531.8350   1541.44  1331082.0
# 2020-09-14  1539.0050  1563.9999  1515.7400   1519.28  1696589.0
# 2020-09-11  1536.0000  1575.2000  1497.3600   1520.72  1597087.0
# 2020-09-10  1560.6400  1584.0810  1525.8050   1532.02  1618557.0
# 2020-09-09  1557.5300  1569.0000  1536.0511   1556.96  1774704.0
# 2020-09-08  1533.5100  1563.8650  1528.0100   1532.39  2610884.0
# 2020-09-04  1624.2600  1645.1100  1547.6125   1591.04  2608568.0
# ...

# %%
val1 = f1.groupby(['date'])["1. open"].sum()
val2 = f1.groupby(['date'])["2. high"].sum()
val3 = f1.groupby(['date'])["3. low"].sum()
val4 = f1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "purple", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "violet", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "v",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737652., 737659., 737669., 737676., 737683., 737690.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h2>FACEBOOK</h2>

# %%
g1 = g.head(30)
g1
# Out:
#             1. open   2. high    3. low  4. close   5. volume
# date
# 2020-09-23  255.260  257.9921  248.1500    249.02  19641266.0
# 2020-09-22  253.310  255.3200  248.2200    254.75  30293103.0
# 2020-09-21  247.540  249.9500  244.1300    248.15  24709378.0
# 2020-09-18  258.405  259.2000  250.0500    252.53  28130767.0
# 2020-09-17  258.280  261.5000  250.1900    254.82  31281441.0
# 2020-09-16  267.290  272.4400  261.7900    263.52  29207594.0
# 2020-09-15  270.670  274.5200  269.3000    272.42  18478530.0
# 2020-09-14  270.950  276.6400  265.7000    266.15  24093830.0
# 2020-09-11  270.060  271.3900  262.6400    266.61  18913883.0
# 2020-09-10  275.510  279.1600  267.0319    268.09  24814669.0
# 2020-09-09  275.770  278.4800  271.3500    273.72  22918769.0
# 2020-09-08  271.280  279.3000  269.4200    271.16  24863997.0
# 2020-09-04  287.250  289.0000  271.1400    282.73  30333671.0
# 2020-09-03  295.990  297.6000  283.6300    291.12  32294092.0
# ...

# %%
val1 = g1.groupby(['date'])["1. open"].sum()
val2 = g1.groupby(['date'])["2. high"].sum()
val3 = g1.groupby(['date'])["3. low"].sum()
val4 = g1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "purple", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "violet", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737652., 737659., 737669., 737676., 737683., 737690.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h2>AMAZON</h2>

# %%
h1 = h.head(30)
h1
# Out:
#               1. open    2. high     3. low  4. close  5. volume
# date
# 2020-09-23  3120.4300  3126.9990  2992.3759   2999.86  5652665.0
# 2020-09-22  3033.8350  3133.9900  3000.2000   3128.99  6948816.0
# 2020-09-21  2906.5000  2962.0000  2871.0000   2960.47  6117925.0
# 2020-09-18  3031.7400  3037.8000  2905.5400   2954.91  8892580.0
# 2020-09-17  3009.2500  3029.4320  2972.5500   3008.73  6449050.0
# 2020-09-16  3179.9900  3187.2380  3074.1500   3078.10  4531189.0
# 2020-09-15  3136.1600  3175.0200  3108.9200   3156.13  4021535.0
# 2020-09-14  3172.9372  3187.3900  3096.0000   3102.97  4529596.0
# 2020-09-11  3208.6900  3217.3409  3083.9800   3116.22  5093982.0
# 2020-09-10  3307.2188  3349.8900  3170.5500   3175.11  5330741.0
# 2020-09-09  3202.9900  3303.1750  3185.0000   3268.61  5188675.0
# 2020-09-08  3144.0000  3250.8450  3130.0000   3149.84  6094205.0
# 2020-09-04  3318.0000  3381.5000  3111.1300   3294.62  8781754.0
# ...

# %%
val1 = h1.groupby(['date'])["1. open"].sum()
val2 = h1.groupby(['date'])["2. high"].sum()
val3 = h1.groupby(['date'])["3. low"].sum()
val4 = h1.groupby(['date'])["4. close"].sum()
plt.figure(figsize = (16,8))
plt.plot(val1, color = "b", ls = "-", marker = "o",label = "OPEN",markeredgecolor = "k",lw = 0.5)
plt.plot(val2, color = "r", ls = "-", marker = "o",label = "HIGH",markeredgecolor = "k",lw = 0.5)
plt.plot(val3, color = "purple", ls = "-", marker = "o",label = "LOW",markeredgecolor = "k",lw = 0.5)
plt.plot(val4, color = "g", ls = "-", marker = "o",label = "CLOSE",markeredgecolor = "k",lw = 0.5)
plt.xlabel('Date')
plt.legend(loc ='upper right')
plt.grid(True)

plt.figure(figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(val1, color = "b", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('OPENING PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(val2, color = "r", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('HIGHEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,3)
plt.plot(val3, color = "violet", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('LOWEST PRICE')
plt.xticks(rotation = 60)
plt.grid(True)
plt.subplot(2,2,4)
plt.plot(val4, color = "g", ls = "-", marker = "o",markeredgecolor = "k")
plt.xlabel('Date')
plt.ylabel('CLOSING PRICE')
plt.grid(True)
plt.xticks(rotation = 60)
# Out:
# (array([737652., 737659., 737669., 737676., 737683., 737690.]),
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# <h2>Machine Learning</h2>

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = c[['2. high','3. low','1. open','5. volume']].values
Y = c[['4. close']].values

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.15,random_state=0)

LR1= LinearRegression()
LR1.fit(X_train,Y_train)

LR1.score(X,Y)

print(LR1.coef_)
print(LR1.intercept_)
# Out:
# [[ 8.11499529e-01  8.09060134e-01 -6.19377742e-01 -9.62992552e-10]]
# [0.05783357]

# %%
predicted_val= LR1.predict(X_test)
print("Predicted values: ", *predicted_val)
print("Actual values: ", *Y_test)
# Out:
# Predicted values:  [210.62021136] [184.97249092] [201.26666996] [212.15845164] [187.090041] [183.60175314] [226.50159776] [197.27137969] [211.81594152] [183.93224924] [212.72016474] [179.13533429] [184.9756208] [217.99754481] [208.3651125]
# Actual values:  [210.28] [183.43] [202.54] [208.25] [188.36] [182.51] [225.53] [196.84] [212.83] [184.68] [214.32] [179.75] [185.36] [217.3] [205.41]
